# %%
from util_functions import *
load_dotenv()
# Out:
# True

# %%
prompts = load_prompts()
# model_name = "Qwen/Qwen2.5-14B-Instruct"
model_name = "Qwen/Qwen2.5-14B-Instruct-1M"
# model_name = "Qwen/Qwen2.5-32B-Instruct"
# model_name = "deepseek-ai/DeepSeek-R1-Distill-Qwen-14B"
# model_name = "deepseek-ai/DeepSeek-R1-Distill-Qwen-32B"

# %%
model, tokenizer = initialize_model(model_name)

# %%
prompts = load_prompts()
client = initialize_client()

# %% [markdown]
# # Qwen2.5 14B 1M

# %%
summary = get_summary(
    system_prompt=prompts['prompts']['comprehensive_300']['content'],
    model=model,
    tokenizer=tokenizer,
    request_origin='file',
    data_input="data.1.json",
    word_limit=300
)
# Out:
# Processing topic: artificial intelligence cyber security
# Number of papers in topic: 7
#
# ====================================================================================================
# TOPIC: ARTIFICIAL INTELLIGENCE CYBER SECURITY
# ====================================================================================================
#
# The integration of artificial intelligence (AI) and machine learning (ML) into smart cities and
# internet of things (IoT) systems seeks to address complex challenges such as efficient resource
# management, enhanced security, and improved service delivery [1]. These technologies are applied
# across various domains, including transportation, energy management, healthcare, and communication
# networks [1].
#
# Intrusion detection systems (IDS) play a pivotal role in securing industrial cyber-physical systems
# (CPS) and IoT networks from malicious activities [2,3]. For instance, DeepFed, a federated deep
# learning scheme, uses convolutional neural networks and gated recurrent units to detect cyber
# threats while ensuring privacy through secure communication protocols [2]. Another study employs
# deep recurrent neural networks in fog computing environments, demonstrating robustness against
# cyber-attacks using the NSL-KDD dataset [3].
#
# Developing comprehensive datasets is crucial for validating AI-based security systems. Notable
# contributions include the TON_IoT datasets, which encompass diverse normal and attack scenarios
# across edge, fog, and cloud tiers, facilitating rigorous evaluation of AI models [4]. Other studies
# utilize established datasets like CSE-CIC IDS-2018, UNSW-NB15, NSL-KDD, and CIDDS-001 to assess the
# efficacy of various machine learning algorithms in IDS, emphasizing accurate classification and
# anomaly detection [5].
#
# A recurring theme is the adaptation of advanced machine learning techniques to meet specific
# security requirements. For example, IntruDTree uses a tree-based model optimized for reduced
# dimensionality and computational efficiency, achieving high performance in predicting unseen test
# cases [6]. Other studies integrate AI and ML into broader smart city initiatives, underscoring their
# potential to enhance urban planning and service delivery [1].
#
# Despite these advancements, challenges persist, particularly regarding ethical implications and
# public perception of AI integration into everyday life [7]. Research highlights the need for
# continued innovation in both technical capabilities and societal acceptance to fully leverage AI and
# ML benefits in smart cities and IoT systems [1,7]. Future work should address security and privacy
# concerns arising from increased reliance on interconnected systems [2,4]. Overall, these studies
# illustrate the transformative potential of AI and ML while acknowledging the need for balanced
# technological and social progress.
#
# References:
# [1] Applications of Artificial Intelligence and Machine learning in smart cities
# [2] DeepFed: Federated Deep Learning for Intrusion Detection in Industrial Cyber–Physical Systems
# [3] Deep recurrent neural network for IoT intrusion detection system
# [4] A new distributed architecture for evaluating AI-based security systems at the edge: Network TON_IoT datasets
# [5] Machine learning methods for cyber security intrusion detection: Datasets and comparative study
# [6] IntruDTree: A Machine Learning-Based Cyber Security Intrusion Detection Model
# [7] Artificial intelligence in Internet of things
# ====================================================================================================
#
# Number of tokens in system prompt: 264
# Number of tokens in papers: 2020
# Number of tokens in output: 448
# Total number of words in output: 332
# Total number of tokens: 2732
#
# The summary exceeds the word limit of 300 words.
#
#
# ====================================================================================================
# UPDATED SUMMARY FOR TOPIC: ARTIFICIAL INTELLIGENCE CYBER SECURITY
# ====================================================================================================
#
# The integration of artificial intelligence (AI) and machine learning (ML) into smart cities and IoT
# systems aims to address challenges such as efficient resource management, enhanced security, and
# improved service delivery [1]. These technologies are applied across domains like transportation,
# energy management, healthcare, and communication networks [1].
#
# Intrusion detection systems (IDS) are critical for securing industrial cyber-physical systems (CPS)
# and IoT networks from malicious activities [2,3]. For instance, DeepFed, a federated deep learning
# scheme, combines convolutional neural networks and gated recurrent units to detect cyber threats
# while ensuring privacy through secure communication protocols [2]. Another study utilizes deep
# recurrent neural networks in fog computing environments, demonstrating robustness against attacks
# using the NSL-KDD dataset [3].
#
# Developing comprehensive datasets is essential for validating AI-based security systems.
# Contributions include the TON_IoT datasets, which cover diverse normal and attack scenarios across
# edge, fog, and cloud tiers, facilitating rigorous evaluation of AI models [4]. Other studies employ
# established datasets like CSE-CIC IDS-2018, UNSW-NB15, NSL-KDD, and CIDDS-001 to assess the efficacy
# of machine learning algorithms in IDS, focusing on accurate classification and anomaly detection
# [5].
#
# A common theme is the adaptation of advanced machine learning techniques to meet specific security
# requirements. For example, IntruDTree uses a tree-based model optimized for reduced dimensionality
# and computational efficiency, achieving high performance in predicting unseen test cases [6]. Other
# studies integrate AI and ML into broader smart city initiatives, underscoring their potential to
# enhance urban planning and service delivery [1].
#
# Despite these advancements, challenges remain, particularly regarding ethical implications and
# public perception of AI integration into daily life [7]. Research emphasizes the need for continued
# innovation in both technical capabilities and societal acceptance to fully leverage AI and ML
# benefits in smart cities and IoT systems [1,7]. Future work should address security and privacy
# concerns arising from increased reliance on interconnected systems [2,4]. Overall, these studies
# illustrate the transformative potential of AI and ML while acknowledging the need for balanced
# technological and social progress.
#
# References:
# [1] Applications of Artificial Intelligence and Machine learning in smart cities
# [2] DeepFed: Federated Deep Learning for Intrusion Detection in Industrial Cyber–Physical Systems
# [3] Deep recurrent neural network for IoT intrusion detection system
# [4] A new distributed architecture for evaluating AI-based security systems at the edge: Network TON_IoT datasets
# [5] Machine learning methods for cyber security intrusion detection: Datasets and comparative study
# [6] IntruDTree: A Machine Learning-Based Cyber Security Intrusion Detection Model
# [7] Artificial intelligence in Internet of things
# ====================================================================================================
#
# Number of tokens in system prompt: 264
# Number of tokens in papers: 2020
# Number of tokens in output: 433
# Total number of words in output: 324
# Total number of tokens: 2717

# %%
summary = get_summary(
    system_prompt=prompts['prompts']['comprehensive_300']['content'],
    model=model,
    tokenizer=tokenizer,
    request_origin='file',
    data_input="data.2.json",
    word_limit=300
)
# Out:
# Processing topic: data visualization
# Number of papers in topic: 6
#
# ====================================================================================================
# TOPIC: DATA VISUALIZATION
# ====================================================================================================
#
# The field of data visualization in scientific research is advancing rapidly, driven by the
# increasing complexity and volume of data generated through techniques like molecular dynamics
# simulations, atomic-level modeling, and genomic sequencing [1,2,3,4,5,6]. This growth underscores
# the need for specialized tools that can effectively process and interpret diverse data types.
#
# **Visualization Tools for Crystallography and Atomistic Simulations**: VESTA 3 provides advanced
# visualization for crystallographic studies, enabling the depiction of crystal morphology and the
# superposition of multiple structural models [1]. OVITO, another tool, supports the visualization and
# analysis of data from atomistic simulations, offering unique analysis, editing, and animation
# functionalities within a user-friendly interface [2]. These tools enhance the understanding of
# molecular interactions and material properties by improving data interpretability.
#
# **Data Collection and Analysis in Macromolecular Crystallography**: The HKL package introduces
# statistical metrics (χ², R-merge) and visualization aids to monitor data collection progress in
# macromolecular crystallography, helping researchers evaluate data quality and identify points of
# diminishing returns [3]. This ensures accurate data reduction and structure solving.
#
# **Next-Generation Web Servers for Deep-Sequencing Data**: DeepTools2 builds on previous versions by
# introducing enhanced functionalities for processing and visualizing deeply sequenced data,
# supporting comprehensive bioinformatics analyses from quality control to integrative explorations
# [4]. This toolset is essential for handling large-scale genomic data, catering to researchers
# requiring robust computational resources.
#
# **Integrative Genomics Data Exploration**: IGV is designed to manage large, heterogeneous genomic
# datasets, supporting both array-based and next-generation sequencing data, as well as clinical and
# phenotypic information [5]. It enables seamless visualization and interaction with complex datasets,
# facilitating integrative genomic studies.
#
# **Dimensionality Reduction Techniques for Single-Cell Data**: UMAP offers a powerful approach for
# reducing dimensions in single-cell data, providing faster runtime, higher reproducibility, and
# clearer cluster organization compared to other methods [6]. This advancement improves the
# interpretability of high-dimensional single-cell data, supporting detailed analyses of tissue
# compositions.
#
# **Common Themes and Methodological Approaches**: A common theme across these tools is the
# integration of advanced visualization techniques to aid in interpreting complex data. Many
# incorporate user-friendly interfaces, scripting capabilities, and extensibility features, enhancing
# their adaptability across various scientific disciplines [1,2,4,5].
#
# **Potential Gaps and Consensus**: While each tool addresses specific data types and analytical
# needs, there remains a need for further development in cross-disciplinary applications and
# interoperability between different visualization platforms [1,2,3,4,5,6]. Ongoing challenges include
# managing ever-growing dataset sizes and ensuring computational efficiency without sacrificing
# analytical depth. Despite these challenges, the consensus among these tools highlights the
# importance of accessible, versatile, and scalable visualization solutions in modern scientific
# research.
#
# References:
# [1] VESTA 3for three-dimensional visualization of crystal, volumetric and morphology data
# [2] Visualization and analysis of atomistic simulation data with OVITO–the Open Visualization Tool
# [3] Processing of X-ray diffraction data collected in oscillation mode
# [4] deepTools2: a next generation web server for deep-sequencing data analysis
# [5] Integrative Genomics Viewer (IGV): high-performance genomics data visualization and exploration
# [6] Dimensionality reduction for visualizing single-cell data using UMAP
# ====================================================================================================
#
# Number of tokens in system prompt: 264
# Number of tokens in papers: 1258
# Number of tokens in output: 583
# Total number of words in output: 410
# Total number of tokens: 2105
#
# The summary exceeds the word limit of 300 words.
#
#
# ====================================================================================================
# UPDATED SUMMARY FOR TOPIC: DATA VISUALIZATION
# ====================================================================================================
#
# The field of data visualization in scientific research is expanding rapidly due to the increasing
# complexity and volume of data from techniques such as molecular dynamics simulations, atomic-level
# modeling, and genomic sequencing [1,2,3,4,5,6]. This growth necessitates specialized tools capable
# of processing and interpreting diverse data types efficiently.
#
# **Visualization Tools for Crystallography and Atomistic Simulations**: VESTA 3 enhances
# crystallographic studies by allowing the visualization of crystal morphology and the superposition
# of multiple structural models [1]. OVITO, meanwhile, supports the visualization and analysis of data
# from atomistic simulations, offering unique analysis, editing, and animation functionalities within
# an intuitive interface [2]. Both tools improve understanding of molecular interactions and material
# properties by enhancing data interpretability.
#
# **Data Collection and Analysis in Macromolecular Crystallography**: The HKL package introduces
# statistical metrics (χ², R-merge) and visualization aids to monitor data collection progress in
# macromolecular crystallography, aiding researchers in evaluating data quality and identifying
# diminishing returns [3]. This ensures accurate data reduction and structure solving.
#
# **Next-Generation Web Servers for Deep-Sequencing Data**: DeepTools2 extends its predecessor by
# adding enhanced functionalities for processing and visualizing deeply sequenced data, supporting
# comprehensive bioinformatics analyses from quality control to integrative explorations [4]. This
# toolset is crucial for handling large-scale genomic data, catering to researchers needing robust
# computational resources.
#
# **Integrative Genomics Data Exploration**: IGV manages large, heterogeneous genomic datasets,
# supporting both array-based and next-generation sequencing data, along with clinical and phenotypic
# information [5]. It facilitates seamless visualization and interaction with complex datasets,
# enabling integrative genomic studies.
#
# **Dimensionality Reduction Techniques for Single-Cell Data**: UMAP provides a powerful approach for
# reducing dimensions in single-cell data, offering faster runtime, higher reproducibility, and
# clearer cluster organization compared to other methods [6]. This advancement improves the
# interpretability of high-dimensional single-cell data, supporting detailed analyses of tissue
# compositions.
#
# **Common Themes and Methodological Approaches**: A recurring theme across these tools is the
# integration of advanced visualization techniques to aid in interpreting complex data. Many tools
# feature user-friendly interfaces, scripting capabilities, and extensibility features, enhancing
# their adaptability across various scientific disciplines [1,2,4,5].
#
# **Potential Gaps and Consensus**: Despite the advancements, each tool primarily addresses specific
# data types and analytical needs, leaving room for further development in cross-disciplinary
# applications and interoperability between different visualization platforms [1,2,3,4,5,6].
# Challenges include managing increasingly large datasets and ensuring computational efficiency
# without compromising analytical depth. Nonetheless, the tools underscore the importance of
# accessible, versatile, and scalable visualization solutions in modern scientific research.
#
# References:
# [1] VESTA 3for three-dimensional visualization of crystal, volumetric and morphology data
# [2] Visualization and analysis of atomistic simulation data with OVITO–the Open Visualization Tool
# [3] Processing of X-ray diffraction data collected in oscillation mode
# [4] deepTools2: a next generation web server for deep-sequencing data analysis
# [5] Integrative Genomics Viewer (IGV): high-performance genomics data visualization and exploration
# [6] Dimensionality reduction for visualizing single-cell data using UMAP
# ====================================================================================================
#
# Number of tokens in system prompt: 264
# Number of tokens in papers: 1258
# Number of tokens in output: 563
# Total number of words in output: 393
# Total number of tokens: 2085

# %%
summary = get_summary(
    system_prompt=prompts['prompts']['strict_300']['content'],
    model=model,
    tokenizer=tokenizer,
    request_origin='file',
    data_input="data.1.json",
    word_limit=300
)
# Out:
# Processing topic: artificial intelligence cyber security
# Number of papers in topic: 7
#
# ====================================================================================================
# TOPIC: ARTIFICIAL INTELLIGENCE CYBER SECURITY
# ====================================================================================================
#
# The integration of artificial intelligence (AI) and machine learning (ML) into smart cities and
# internet of things (IoT) networks is pivotal for addressing complex urban challenges and enhancing
# security [1]. Smart cities leverage AI, ML, and deep reinforcement learning (DRL) to optimize
# policies in areas such as intelligent transportation systems, cyber-security, and smart grid
# management [1]. Similarly, in industrial cyber-physical systems (CPSs), federated deep learning
# (FDL) frameworks like DeepFed are crucial for detecting cyber threats by enabling collaborative
# model training across multiple CPSs without exposing sensitive data [2].
#
# For IoT networks, AI-based intrusion detection systems (IDS) have emerged as effective tools for
# safeguarding against cyber-attacks [3,6]. A deep recurrent neural network (DRNN) was specifically
# designed for fog computing security, demonstrating robustness against various attack vectors [3].
# Another approach, IntruDTree, utilizes a tree-based machine learning model optimized for feature
# selection, improving prediction accuracy while reducing computational overhead [6].
#
# To enhance the evaluation of AI-based security systems, a novel distributed architecture was
# introduced, generating 'TON_IoT' datasets that encompass diverse attack scenarios and normal
# behaviors [4]. These datasets were validated using machine learning algorithms, highlighting their
# utility in assessing the performance of IDS models [4]. Additionally, a comparative study analyzed
# the effectiveness of different machine learning algorithms—such as SVM, KNN, and Decision Trees—on
# widely-used datasets like CSE-CIC IDS-2018 and NSL-KDD [5].
#
# Despite advancements, significant challenges remain, including the need for high-quality training
# data and robust models capable of adapting to evolving threats [1,2,4]. The ethical implications and
# public perception of AI in IoT underscore the importance of balancing innovation with societal trust
# [7]. Overall, the convergence of AI and IoT promises substantial benefits but necessitates ongoing
# research to address security concerns and ethical considerations.
#
# References:
# [1] Applications of Artificial Intelligence and Machine learning in smart cities
# [2] DeepFed: Federated Deep Learning for Intrusion Detection in Industrial Cyber–Physical Systems
# [3] Deep recurrent neural network for IoT intrusion detection system
# [4] A new distributed architecture for evaluating AI-based security systems at the edge: Network TON_IoT datasets
# [5] Machine learning methods for cyber security intrusion detection: Datasets and comparative study
# [6] IntruDTree: A Machine Learning-Based Cyber Security Intrusion Detection Model
# [7] Artificial intelligence in Internet of things
# ====================================================================================================
#
# Number of tokens in system prompt: 228
# Number of tokens in papers: 2020
# Number of tokens in output: 390
# Total number of words in output: 281
# Total number of tokens: 2638

# %%
summary = get_summary(
    system_prompt=prompts['prompts']['strict_300']['content'],
    model=model,
    tokenizer=tokenizer,
    request_origin='file',
    data_input="data.2.json",
    word_limit=300
)
# Out:
# Processing topic: data visualization
# Number of papers in topic: 6
#
# ====================================================================================================
# TOPIC: DATA VISUALIZATION
# ====================================================================================================
#
# The analysis of complex scientific data, particularly in crystallography, genomics, and single-cell
# biology, has seen significant advancements through specialized visualization tools. VESTA, updated
# to version 3, offers comprehensive three-dimensional visualization capabilities for crystallographic
# studies, including the drawing of crystal morphologies and the integration of volumetric data,
# enhancing the understanding of atomic arrangements and electronic states [1]. Similarly, OVITO
# provides an advanced, extensible platform for the post-processing of atomistic simulation data,
# enabling detailed analysis, editing, and animation functionalities through an intuitive interface
# [2].
#
# In macromolecular crystallography, the HKL package's integration of statistical tools and
# visualization aids in monitoring data collection progress, ensuring accuracy and efficiency in
# solving complex structures [3]. This iterative approach is complemented by deepTools2, which
# facilitates comprehensive bioinformatics workflows, incorporating quality control, normalization,
# clustering, and visualization of deep-sequencing data, thereby streamlining the analysis process for
# genomics research [4].
#
# The Integrative Genomics Viewer (IGV) addresses the challenge of handling large, diverse genomic
# data sets by providing high-performance visualization and exploration across various resolutions,
# integrating clinical and phenotypic data for comprehensive insights [5]. For single-cell data, UMAP
# emerges as a robust dimensionality-reduction technique, offering faster computation, higher
# reproducibility, and meaningful organization of cell clusters compared to other methods, thus
# improving the interpretability of complex biological data [6].
#
# These tools collectively highlight the importance of visualization in facilitating the comprehension
# and analysis of intricate scientific datasets, emphasizing both the necessity for specialized
# software and the ongoing evolution of these tools to meet the demands of increasingly complex data.
#
# References:
# [1] VESTA 3for three-dimensional visualization of crystal, volumetric and morphology data
# [2] Visualization and analysis of atomistic simulation data with OVITO–the Open Visualization Tool
# [3] Processing of X-ray diffraction data collected in oscillation mode
# [4] deepTools2: a next generation web server for deep-sequencing data analysis
# [5] Integrative Genomics Viewer (IGV): high-performance genomics data visualization and exploration
# [6] Dimensionality reduction for visualizing single-cell data using UMAP
# ====================================================================================================
#
# Number of tokens in system prompt: 228
# Number of tokens in papers: 1258
# Number of tokens in output: 340
# Total number of words in output: 247
# Total number of tokens: 1826

# %%
summary = get_summary(
    system_prompt=prompts['prompts']['strict_250']['content'],
    model=model,
    tokenizer=tokenizer,
    request_origin='file',
    data_input="data.2.json",
    word_limit=250
)
# Out:
# Processing topic: data visualization
# Number of papers in topic: 6
#
# ====================================================================================================
# TOPIC: DATA VISUALIZATION
# ====================================================================================================
#
# Visualization tools play a crucial role in interpreting complex datasets across various scientific
# fields. In crystallographic studies, VESTA 3 offers advanced functionalities for three-dimensional
# visualization, including drawing crystal morphologies, superimposing multiple models, and
# calculating densities [1]. Similarly, OVITO is tailored for post-processing atomistic simulation
# data, offering unique analysis and editing capabilities alongside Python scripting and plugin
# extensibility [2]. These tools exemplify the trend towards enhanced visualization and manipulation
# of intricate data structures.
#
# In the realm of genomics, deepTools2 and the Integrative Genomics Viewer (IGV) address the
# challenges posed by large, diverse datasets generated by modern sequencing techniques. DeepTools2
# provides a comprehensive suite of tools for analyzing deep-sequencing data, with a particular
# emphasis on visualization and integration within the Galaxy framework [4]. IGV stands out for its
# ability to handle heterogeneous data sets, supporting both array-based and next-generation
# sequencing data, as well as integrating clinical and phenotypic information [5]. Both tools
# prioritize user-friendly interfaces and high-performance visualization to facilitate efficient data
# exploration and hypothesis testing.
#
# Dimensionality reduction techniques are pivotal in simplifying high-dimensional biological data for
# better interpretability. UMAP, a nonlinear method, demonstrates superior performance in organizing
# cell clusters compared to other tools, ensuring faster run times and higher reproducibility [6].
# This capability is particularly valuable in single-cell studies, enhancing the visualization and
# understanding of complex cellular compositions. Together, these advancements underscore the evolving
# landscape of data visualization tools, catering to increasingly sophisticated experimental outputs
# and analytical needs.
#
# References:
# [1] VESTA 3for three-dimensional visualization of crystal, volumetric and morphology data
# [2] Visualization and analysis of atomistic simulation data with OVITO–the Open Visualization Tool
# [3] Processing of X-ray diffraction data collected in oscillation mode
# [4] deepTools2: a next generation web server for deep-sequencing data analysis
# [5] Integrative Genomics Viewer (IGV): high-performance genomics data visualization and exploration
# [6] Dimensionality reduction for visualizing single-cell data using UMAP
# ====================================================================================================
#
# Number of tokens in system prompt: 288
# Number of tokens in papers: 1258
# Number of tokens in output: 314
# Total number of words in output: 237
# Total number of tokens: 1860

# %%
summary = get_summary(
    system_prompt=prompts['prompts']['two_paragraph']['content'],
    model=model,
    tokenizer=tokenizer,
    request_origin='file',
    data_input="data.2.json",
    word_limit=250
)
# Out:
# Processing topic: data visualization
# Number of papers in topic: 6
#
# ====================================================================================================
# TOPIC: DATA VISUALIZATION
# ====================================================================================================
#
# The first paragraph introduces VESTA 3 and OVITO as powerful tools for three-dimensional
# visualization and analysis in crystallographic and atomistic simulation studies, respectively. VESTA
# 3 [1] offers advanced features such as morphological drawing, density calculations, and
# sophisticated bond searches, enhancing the accuracy and efficiency of crystallographic data
# analysis. OVITO [2], on the other hand, integrates unique analysis and editing functionalities for
# atomistic data, providing a versatile platform for post-processing simulations with an easy-to-use
# interface and scripting capabilities.
#
# Key findings highlight the effectiveness of these tools in handling complex data structures and
# improving the interpretability of results. VESTA 3's ability to calculate and visualize densities
# and isosurfaces facilitates a deeper understanding of crystal structures, while OVITO's analysis
# functions and Python scripting support enhance the manipulation and interpretation of atomistic
# simulation outcomes. Additionally, deepTools2 [4] and the Integrative Genomics Viewer (IGV) [5]
# offer robust solutions for deep-sequencing and genomic data visualization, respectively. DeepTools2
# provides comprehensive tools for normalization, clustering, and visualization of sequencing data,
# while IGV excels in integrating diverse genomic data types, including clinical and phenotypic
# information. UMAP [6], a nonlinear dimensionality-reduction technique, stands out for its superior
# performance in visualizing single-cell data, offering faster computation times and more reproducible
# cluster organization compared to other methods. These tools collectively advance data visualization
# and interpretation across various scientific domains.
#
# References:
# [1] VESTA 3for three-dimensional visualization of crystal, volumetric and morphology data
# [2] Visualization and analysis of atomistic simulation data with OVITO–the Open Visualization Tool
# [3] Processing of X-ray diffraction data collected in oscillation mode
# [4] deepTools2: a next generation web server for deep-sequencing data analysis
# [5] Integrative Genomics Viewer (IGV): high-performance genomics data visualization and exploration
# [6] Dimensionality reduction for visualizing single-cell data using UMAP
# ====================================================================================================
#
# Number of tokens in system prompt: 327
# Number of tokens in papers: 1258
# Number of tokens in output: 304
# Total number of words in output: 217
# Total number of tokens: 1889

# %%
summary = get_summary(
    system_prompt=prompts['prompts']['single_paragraph']['content'],
    model=model,
    tokenizer=tokenizer,
    request_origin='file',
    data_input="data.2.json",
    word_limit=250
)
# Out:
# Processing topic: data visualization
# Number of papers in topic: 6
#
# ====================================================================================================
# TOPIC: DATA VISUALIZATION
# ====================================================================================================
#
# Visualization and analysis of complex scientific data have become increasingly critical with
# advancements in technologies generating vast datasets across various fields. VESTA 3 [1] offers
# advanced three-dimensional visualization capabilities for crystallographic studies, enhancing
# functionalities such as morphology drawing, density calculations, and improved performance in
# rendering isosurfaces. Similarly, OVITO [2] provides a comprehensive toolset for post-processing
# atomistic simulation data, integrating analysis and editing features through an intuitive graphical
# interface. In contrast, deepTools2 [4] focuses on deep-sequencing data, offering robust tools for
# quality control, normalization, and integrative analyses, accessible via a web server or command-
# line interface. For genomic data, the Integrative Genomics Viewer (IGV) [5] efficiently manages
# large, diverse datasets, supporting integration of various types of genomic, clinical, and
# phenotypic data, ensuring high-performance visualization. Additionally, UMAP [6] demonstrates
# superior performance in dimensionality reduction for single-cell data, outperforming other methods
# in speed, reproducibility, and cluster organization, thus enhancing the interpretability of complex
# biological datasets. These tools collectively address the growing need for efficient and accurate
# data analysis across diverse scientific domains, emphasizing both visual clarity and computational
# efficiency.
#
# References:
# [1] VESTA 3for three-dimensional visualization of crystal, volumetric and morphology data
# [2] Visualization and analysis of atomistic simulation data with OVITO–the Open Visualization Tool
# [3] Processing of X-ray diffraction data collected in oscillation mode
# [4] deepTools2: a next generation web server for deep-sequencing data analysis
# [5] Integrative Genomics Viewer (IGV): high-performance genomics data visualization and exploration
# [6] Dimensionality reduction for visualizing single-cell data using UMAP
# ====================================================================================================
#
# Number of tokens in system prompt: 334
# Number of tokens in papers: 1258
# Number of tokens in output: 251
# Total number of words in output: 175
# Total number of tokens: 1843

# %%
summary = get_summary(
    system_prompt=prompts['prompts']['single_paragraph']['content'],
    model=model,
    tokenizer=tokenizer,
    request_origin='api',
    data_input="artificial intelligence agriculture",
    word_limit=250
)
# Out:
# Processing topic: artificial intelligence agriculture
# Number of papers in topic: 5
#
# ====================================================================================================
# TOPIC: ARTIFICIAL INTELLIGENCE AGRICULTURE
# ====================================================================================================
#
# In the context of the Fourth Industrial Revolution, machine learning (ML) is pivotal for analyzing
# vast digital datasets across various sectors, including agriculture [1,2]. Supervised, unsupervised,
# semi-supervised, and reinforcement learning algorithms, alongside deep learning, enable intelligent
# data analysis, enhancing application capabilities in areas like cybersecurity, smart cities, and
# healthcare [1,2]. In agriculture, ML applications span crop management, disease and weed detection,
# livestock welfare monitoring, water and soil management [3]. Precision agriculture leverages
# computer vision integrated with AI algorithms to detect patterns and improve grain production
# efficiency, focusing on disease detection, quality assessment, and phenotyping for major crops [4].
# Advanced techniques, such as Deep Belief Networks and GPU utilization, promise robust methods for
# image processing in agriculture [4]. Moreover, smart farming systems employ data management
# strategies to optimize resource use and environmental protection, paving the way for sustainable
# agricultural practices under the emerging Agriculture 5.0 paradigm [5]. Collectively, these
# advancements underscore the transformative potential of ML and AI in addressing global agricultural
# challenges and ensuring sustainable food production.
#
# References:
# [1] Machine Learning: Algorithms, Real-World Applications and Research Directions
# [2] Machine Learning: Algorithms, Real-World Applications and Research Directions
# [3] Machine Learning in Agriculture: A Review
# [4] Computer vision and artificial intelligence in precision agriculture for grain crops: A systematic review
# [5] From Smart Farming towards Agriculture 5.0: A Review on Crop Data Management
# ====================================================================================================
#
# Number of tokens in system prompt: 334
# Number of tokens in papers: 1225
# Number of tokens in output: 220
# Total number of words in output: 167
# Total number of tokens: 1779

# %%
summary = get_summary(
    system_prompt=prompts['prompts']['single_paragraph']['content'],
    model=model,
    tokenizer=tokenizer,
    request_origin='api',
    data_input="artificial intelligence agriculture",
    word_limit=250
)
# Out:
# Processing topic: artificial intelligence agriculture
# Number of papers in topic: 5
#
# ====================================================================================================
# TOPIC: ARTIFICIAL INTELLIGENCE AGRICULTURE
# ====================================================================================================
#
# In the era of the Fourth Industrial Revolution, machine learning (ML) stands as a pivotal tool for
# analyzing vast datasets across diverse sectors, including agriculture, where it enhances decision-
# making and operational efficiency [1,2]. ML encompasses various algorithms, such as supervised,
# unsupervised, semi-supervised, reinforcement learning, and deep learning, each tailored to address
# specific challenges in real-world applications [1,2]. In agriculture, ML is applied to crop and
# livestock management, water and soil management, and disease detection, offering valuable insights
# and actionable recommendations for farmers [3]. For instance, in precision agriculture, computer
# vision combined with AI algorithms has significantly improved disease detection and phenotyping for
# major grain crops like maize, rice, wheat, soybean, and barley, leveraging GPU and advanced
# techniques like Deep Belief Networks [4]. These advancements facilitate the transition from smart
# farming to Agriculture 5.0, characterized by robust data management systems that optimize resource
# usage and environmental protection, thereby ensuring sustainable agricultural practices capable of
# meeting future demands [5]. Ultimately, the integration of ML and AI technologies in agriculture
# promises enhanced productivity, reduced environmental impact, and more informed decision-making
# processes.
#
# References:
# [1] Machine Learning: Algorithms, Real-World Applications and Research Directions
# [2] Machine Learning: Algorithms, Real-World Applications and Research Directions
# [3] Machine Learning in Agriculture: A Review
# [4] Computer vision and artificial intelligence in precision agriculture for grain crops: A systematic review
# [5] From Smart Farming towards Agriculture 5.0: A Review on Crop Data Management
# ====================================================================================================
#
# Number of tokens in system prompt: 334
# Number of tokens in papers: 1225
# Number of tokens in output: 233
# Total number of words in output: 178
# Total number of tokens: 1792

# %%
summary = get_summary(
    system_prompt=prompts['prompts']['single_paragraph']['content'],
    model=model,
    tokenizer=tokenizer,
    request_origin='api',
    data_input="machine learning medicine",
    word_limit=250
)
# Out:
# Processing topic: machine learning medicine
# Number of papers in topic: 5
#
# ====================================================================================================
# TOPIC: MACHINE LEARNING MEDICINE
# ====================================================================================================
#
# Machine learning's potential to revolutionize medicine is increasingly recognized, yet significant
# challenges remain in translating theoretical advancements into practical clinical care [2]. By
# analyzing vast datasets, machine learning can enhance prognosis, automate diagnostics, and improve
# treatment accuracy [1,3]. For instance, predictive models can offer insights into patient outcomes
# and support radiological and pathological analyses [3]. However, despite the availability of
# sophisticated algorithms and large datasets, few machine learning applications have significantly
# impacted clinical practices, suggesting that current methodologies may face hurdles such as data
# quality, interpretability, and privacy concerns [2]. One notable privacy issue involves model
# inversion attacks, where adversaries exploit confidence information from machine learning models to
# infer sensitive data, such as genomic information or personal lifestyle choices, highlighting the
# need for robust countermeasures to protect individual privacy [4]. Additionally, tools like ProTox-
# II leverage machine learning to predict chemical toxicity across multiple endpoints, aiding
# regulatory assessments and pharmaceutical development [5]. These advancements underscore the
# transformative potential of machine learning in medicine, though addressing technical and ethical
# challenges will be crucial for widespread adoption [2].
#
# References:
# [1] Machine Learning in Medicine
# [2] Machine Learning in Medicine
# [3] Predicting the Future — Big Data, Machine Learning, and Clinical Medicine
# [4] Model Inversion Attacks that Exploit Confidence Information and Basic Countermeasures
# [5] ProTox-II: a webserver for the prediction of toxicity of chemicals
# ====================================================================================================
#
# Number of tokens in system prompt: 334
# Number of tokens in papers: 998
# Number of tokens in output: 216
# Total number of words in output: 175
# Total number of tokens: 1548

# %% [markdown]
# # TGI

# %%
summary = get_summary(
    system_prompt=prompts['prompts']['single_paragraph']['content'],
    client=client,
    request_origin='api',
    data_input="artificial intelligence agriculture"
)
# Out:
# Processing topic: artificial intelligence agriculture
# Number of papers in topic: 5
#
# ====================================================================================================
# TOPIC: ARTIFICIAL INTELLIGENCE AGRICULTURE
# ====================================================================================================
#
# In the era of the Fourth Industrial Revolution, machine learning (ML) has become crucial for
# analyzing diverse digital data to enhance real-world applications across sectors like cybersecurity,
# healthcare, and agriculture [1,2]. Supervised, unsupervised, semi-supervised, and reinforcement
# learning algorithms, alongside deep learning techniques, enable intelligent data analysis on a large
# scale [1,2]. In agriculture, ML is particularly impactful, offering solutions for crop management,
# including yield prediction, disease detection, and species recognition, as well as for livestock and
# water management [3,5]. Precision agriculture benefits from computer vision combined with AI,
# especially for disease detection and grain quality assessment in major crops like maize, rice, and
# wheat [4]. These technologies, leveraging GPU processing and advanced AI techniques, promise robust
# computer vision methods for precision agriculture. Moreover, the integration of robotic solutions
# with AI in smart farming systems facilitates efficient data management, optimizing resource use and
# environmental sustainability [5]. The most significant conclusion is that ML and AI are pivotal in
# transforming agriculture into a data-driven, sustainable, and efficient industry, capable of meeting
# future food demands [1-5].
#
# References:
# [1] Machine Learning: Algorithms, Real-World Applications and Research Directions
# [2] Machine Learning: Algorithms, Real-World Applications and Research Directions
# [3] Machine Learning in Agriculture: A Review
# [4] Computer vision and artificial intelligence in precision agriculture for grain crops: A systematic review
# [5] From Smart Farming towards Agriculture 5.0: A Review on Crop Data Management
# ====================================================================================================
#
# Number of tokens in system prompt: 1571
# Number of tokens in output: 228
# Total number of words in output: 173
# Total number of tokens: 1799
